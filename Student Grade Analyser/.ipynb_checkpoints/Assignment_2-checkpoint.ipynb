# %%
file_name = "expenses.txt"
def load_expenses(filename):
    expenses = []
    try:
        with open(filename, "r") as f:
            for line in f:
                line = line.strip()
                if line:
                    category, amount = line.split(",")
                    expenses.append((category, amount.strip()))
    except FileNotFoundError:
        print(f"File '{filename}' not found. Starting with empty list.")
    return expenses

load_expenses(file_name)
# Out:
# [('Food', '150'),
#  ('Transport', '60'),
#  ('Food', '200'),
#  ('Entertainment', '120'),
#  ('Utilities', '300'),
#  ('Transport', '45'),
#  ('Sport', '50'),
#  ('Games', '45'),
#  ('Food', '500'),
#  ('Food', '500')]

# %%
def add_expense(filename, category, amount):
    if amount <= 0:
        raise ValueError(f"Amount must be positive, got {amount}")
    with open(filename, "a") as f:
        f.write(f"{category},{amount}\n")

add_expense(file_name, "Food", 500)
load_expenses(file_name)
# Out:
# [('Food', '150'),
#  ('Transport', '60'),
#  ('Food', '200'),
#  ('Entertainment', '120'),
#  ('Utilities', '300'),
#  ('Transport', '45'),
#  ('Sport', '50'),
#  ('Games', '45'),
#  ('Food', '500')]

# %%
def category_totals(expenses):
    total_amount = {}
    for category, amount in expenses:
        amount = float(amount)
        total_amount[category] = total_amount.get(category, 0) + amount

    print(f"\n{'Category':<15}  Total")
    print("─" * 25)
    for category, total in total_amount.items():
        print(f"{category:<15}: ${total:.2f}")
    print("─" * 25)

    grand_total = sum(total_amount.values())
    print(f"{'Grand Total':<15}: ${grand_total:.2f}")

category_totals(load_expenses(file_name))
# Out:
# Category         Total
# ─────────────────────────
# Food           : $850.00
# Transport      : $105.00
# Entertainment  : $120.00
# Utilities      : $300.00
# Sport          : $50.00
# Games          : $45.00
# ─────────────────────────
# Grand Total    : $1470.00

# %%
def above_threshold(expenses, limit):
    result = [(category, float(amount)) for category, amount in expenses if float(amount) > limit]
    return result

above_threshold(load_expenses(file_name), 100)
# Out:
# [('Food', 150.0),
#  ('Food', 200.0),
#  ('Entertainment', 120.0),
#  ('Utilities', 300.0),
#  ('Food', 500.0)]

# %%
expenses = load_expenses(filename)
category_totals(expenses)

print(f"\nExpenses above $100:")
high_expenses = above_threshold(expenses, 100)
for category, amount in high_expenses:
     print(f"  {category:<15} → ${amount:.2f}")


print("\n--- Adding new expense: Food, 500 ---")
try:
    add_expense(filename, "Food", 500)
    expenses = load_expenses(filename)
    category_totals(expenses)
except ValueError as e:
    print(f"Error: {e}")


print("\n--- Testing invalid amount ---")
try:
     add_expense(filename, "Food", -50)
except ValueError as e:
    print(f"Caught ValueError → {e}")
# Out:
# Category         Total
# ─────────────────────────
# Food           : $850.00
# Transport      : $105.00
# Entertainment  : $120.00
# Utilities      : $300.00
# Sport          : $50.00
# Games          : $45.00
# ─────────────────────────
# Grand Total    : $1470.00
#
# Expenses above $100:
#   Food            → $150.00
#   Food            → $200.00
#   Entertainment   → $120.00
#   Utilities       → $300.00
#   Food            → $500.00
#
# --- Adding new expense: Food, 500 ---
#
# Category         Total
# ─────────────────────────
# Food           : $1350.00
# Transport      : $105.00
# Entertainment  : $120.00
# Utilities      : $300.00
# Sport          : $50.00
# Games          : $45.00
# ─────────────────────────
# Grand Total    : $1970.00
#
# --- Testing invalid amount ---
# Caught ValueError → Amount must be positive, got -50
